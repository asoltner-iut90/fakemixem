# %% [raw]
# {
#  "cells": [
#   {
#    "metadata": {},
#    "cell_type": "raw",
#    "outputs": [],
#    "execution_count": null,
#    "source": [
#     "{\n",
#     " \"cells\": [\n",
#     "  {\n",
#     "   \"metadata\": {\n",
#     "    \"ExecuteTime\": {\n",
#     "     \"end_time\": \"2025-11-04T13:18:58.445026Z\",\n",
#     "     \"start_time\": \"2025-11-04T13:18:57.661064Z\"\n",
#     "    }\n",
#     "   },\n",
#     "   \"cell_type\": \"code\",\n",
#     "   \"source\": [\n",
#     "    \"import pandas as pd\\n\",\n",
#     "    \"import re\\n\"\n",
#     "   ],\n",
#     "   \"id\": \"a1da23d8216dd7a5\",\n",
#     "   \"outputs\": [],\n",
#     "   \"execution_count\": 4\n",
#     "  },\n",
#     "  {\n",
#     "   \"metadata\": {\n",
#     "    \"ExecuteTime\": {\n",
#     "     \"end_time\": \"2025-11-04T13:24:19.528392Z\",\n",
#     "     \"start_time\": \"2025-11-04T13:24:19.525060Z\"\n",
#     "    }\n",
#     "   },\n",
#     "   \"cell_type\": \"code\",\n",
#     "   \"source\": \"sponsors = []\",\n",
#     "   \"id\": \"b25025d20be38846\",\n",
#     "   \"outputs\": [],\n",
#     "   \"execution_count\": 7\n",
#     "  },\n",
#     "  {\n",
#     "   \"metadata\": {\n",
#     "    \"ExecuteTime\": {\n",
#     "     \"end_time\": \"2025-11-04T13:44:16.176323Z\",\n",
#     "     \"start_time\": \"2025-11-04T13:44:16.169237Z\"\n",
#     "    }\n",
#     "   },\n",
#     "   \"cell_type\": \"code\",\n",
#     "   \"source\": [\n",
#     "    \"\\n\",\n",
#     "    \"def add_sponsor(domain, name, description):\\n\",\n",
#     "    \"    sponsor = {\\n\",\n",
#     "    \"        \\\"domains\\\": [domain],\\n\",\n",
#     "    \"        \\\"name\\\": name,\\n\",\n",
#     "    \"        \\\"description\\\": description\\n\",\n",
#     "    \"    }\\n\",\n",
#     "    \"    sponsors.append(sponsor)\\n\",\n",
#     "    \"\\n\",\n",
#     "    \"def add_domain(domain, name):\\n\",\n",
#     "    \"    for sponsor in sponsors:\\n\",\n",
#     "    \"        if name == sponsor[\\\"name\\\"]:\\n\",\n",
#     "    \"            if domain not in sponsor[\\\"domains\\\"]:\\n\",\n",
#     "    \"                sponsor[\\\"domains\\\"].append(domain)\\n\",\n",
#     "    \"            return\\n\",\n",
#     "    \"    add_sponsor(domain, name, \\\"\\\")\\n\",\n",
#     "    \"\\n\",\n",
#     "    \"\\n\",\n",
#     "    \"def process_sponsor_domain(domain):\\n\",\n",
#     "    \"    for sponsor in sponsors:\\n\",\n",
#     "    \"        if domain in sponsor[\\\"domains\\\"]:\\n\",\n",
#     "    \"            return\\n\",\n",
#     "    \"    print(f\\\"New sponsor domain found: {domain}\\\")\\n\",\n",
#     "    \"    name = \\\"\\\"\\n\",\n",
#     "    \"    while name == \\\"\\\":\\n\",\n",
#     "    \"        name = input(f\\\"Please provide the sponsor name for '{domain}' (or leave blank to skip):\\\").strip()\\n\",\n",
#     "    \"    add_domain(domain, name)\\n\"\n",
#     "   ],\n",
#     "   \"id\": \"f11ebf57466e5102\",\n",
#     "   \"outputs\": [],\n",
#     "   \"execution_count\": 24\n",
#     "  },\n",
#     "  {\n",
#     "   \"metadata\": {\n",
#     "    \"ExecuteTime\": {\n",
#     "     \"end_time\": \"2025-11-04T14:58:37.496253Z\",\n",
#     "     \"start_time\": \"2025-11-04T14:58:37.480579Z\"\n",
#     "    }\n",
#     "   },\n",
#     "   \"cell_type\": \"code\",\n",
#     "   \"source\": [\n",
#     "    \"import csv\\n\",\n",
#     "    \"\\n\",\n",
#     "    \"def save_to_csv(data, file):\\n\",\n",
#     "    \"    with open(file, \\\"w\\\", newline=\\\"\\\", encoding=\\\"utf-8\\\") as f:\\n\",\n",
#     "    \"        writer = csv.DictWriter(f, fieldnames=data[0].keys())\\n\",\n",
#     "    \"        writer.writeheader()\\n\",\n",
#     "    \"        writer.writerows(data)\"\n",
#     "   ],\n",
#     "   \"id\": \"1b940358e846ccdc\",\n",
#     "   \"outputs\": [],\n",
#     "   \"execution_count\": 33\n",
#     "  },\n",
#     "  {\n",
#     "   \"metadata\": {\n",
#     "    \"ExecuteTime\": {\n",
#     "     \"end_time\": \"2025-11-04T13:44:17.853995Z\",\n",
#     "     \"start_time\": \"2025-11-04T13:44:17.848670Z\"\n",
#     "    }\n",
#     "   },\n",
#     "   \"cell_type\": \"code\",\n",
#     "   \"source\": [\n",
#     "    \"def get_links(text):\\n\",\n",
#     "    \"    url_pattern = re.compile(r'(https?://[^\\\\s]+)')\\n\",\n",
#     "    \"    return url_pattern.findall(text)\\n\",\n",
#     "    \"\\n\",\n",
#     "    \"def extract_domain(url):\\n\",\n",
#     "    \"    domain_pattern = re.compile(r'https?://(www\\\\.)?([^/]+)')\\n\",\n",
#     "    \"    match = domain_pattern.match(url)\\n\",\n",
#     "    \"    if match:\\n\",\n",
#     "    \"        return match.group(2)\\n\",\n",
#     "    \"    return None\"\n",
#     "   ],\n",
#     "   \"id\": \"18855cec0464ceeb\",\n",
#     "   \"outputs\": [],\n",
#     "   \"execution_count\": 25\n",
#     "  },\n",
#     "  {\n",
#     "   \"metadata\": {\n",
#     "    \"ExecuteTime\": {\n",
#     "     \"end_time\": \"2025-11-04T13:25:04.541232Z\",\n",
#     "     \"start_time\": \"2025-11-04T13:25:04.490848Z\"\n",
#     "    }\n",
#     "   },\n",
#     "   \"cell_type\": \"code\",\n",
#     "   \"source\": \"amixem_dataset = pd.read_csv(\\\"amixem_20251023.csv\\\")\",\n",
#     "   \"id\": \"c4880410b13861fc\",\n",
#     "   \"outputs\": [],\n",
#     "   \"execution_count\": 11\n",
#     "  },\n",
#     "  {\n",
#     "   \"metadata\": {\n",
#     "    \"ExecuteTime\": {\n",
#     "     \"end_time\": \"2025-11-04T14:50:36.300563Z\",\n",
#     "     \"start_time\": \"2025-11-04T13:46:59.987278Z\"\n",
#     "    }\n",
#     "   },\n",
#     "   \"cell_type\": \"code\",\n",
#     "   \"source\": [\n",
#     "    \"for index, video in amixem_dataset.iterrows():\\n\",\n",
#     "    \"    if video[\\\"sponsored\\\"]:\\n\",\n",
#     "    \"        description = video[\\\"description\\\"]\\n\",\n",
#     "    \"        links = get_links(description)\\n\",\n",
#     "    \"        for link in links:\\n\",\n",
#     "    \"            domain = extract_domain(link)\\n\",\n",
#     "    \"            if domain:\\n\",\n",
#     "    \"                process_sponsor_domain(domain)\"\n",
#     "   ],\n",
#     "   \"id\": \"6aa4ce3ee0a65269\",\n",
#     "   \"outputs\": [\n",
#     "    {\n",
#     "     \"name\": \"stdout\",\n",
#     "     \"output_type\": \"stream\",\n",
#     "     \"text\": [\n",
#     "      \"New sponsor domain found: hellofresh.fr\\n\",\n",
#     "      \"New sponsor domain found: youtube.com\\n\",\n",
#     "      \"New sponsor domain found: fr.weareholy.com\\n\",\n",
#     "      \"New sponsor domain found: nordvpn.com\\n\",\n",
#     "      \"New sponsor domain found: ultrapremiumdirect.com\\n\",\n",
#     "      \"New sponsor domain found: revolutbusiness.onelink.me\\n\",\n",
#     "      \"New sponsor domain found: lespetitspres.fr\\n\",\n",
#     "      \"New sponsor domain found: vinted.shop\\n\",\n",
#     "      \"New sponsor domain found: vision-naire.com\\n\",\n",
#     "      \"New sponsor domain found: rosefestival.fr\\n\",\n",
#     "      \"New sponsor domain found: mate-cito.com\\n\",\n",
#     "      \"New sponsor domain found: kganimation.fr\\n\",\n",
#     "      \"New sponsor domain found: ibis.accor.com\\n\",\n",
#     "      \"New sponsor domain found: instagram.com\\n\",\n",
#     "      \"New sponsor domain found: tiktok.com\\n\",\n",
#     "      \"New sponsor domain found: saily.com\\n\",\n",
#     "      \"New sponsor domain found: deliveroo.fr\\n\",\n",
#     "      \"New sponsor domain found: order.store\\n\",\n",
#     "      \"New sponsor domain found: odoo.com\\n\",\n",
#     "      \"New sponsor domain found: emma.fr\\n\",\n",
#     "      \"New sponsor domain found: url.rhinoshield.fr\\n\",\n",
#     "      \"New sponsor domain found: paulmirabel.com\\n\",\n",
#     "      \"New sponsor domain found: infinitynikki.onelink.me\\n\",\n",
#     "      \"New sponsor domain found: detectivebox.fr\\n\",\n",
#     "      \"New sponsor domain found: amazon.fr\\n\",\n",
#     "      \"New sponsor domain found: airup.link\\n\",\n",
#     "      \"New sponsor domain found: wo.ws\\n\",\n",
#     "      \"New sponsor domain found: 24hpourfaireunson.odoo.com\\n\",\n",
#     "      \"New sponsor domain found: music.petitbiscuit.fr\\n\",\n",
#     "      \"New sponsor domain found: linktr.ee\\n\",\n",
#     "      \"New sponsor domain found: forms.gle\\n\",\n",
#     "      \"New sponsor domain found: adopte.app\\n\",\n",
#     "      \"New sponsor domain found: sylvain-chanteur.fr\\n\",\n",
#     "      \"New sponsor domain found: visa.fr\\n\",\n",
#     "      \"New sponsor domain found: mangerbouger.fr\\n\",\n",
#     "      \"New sponsor domain found: youtu.be\\n\",\n",
#     "      \"New sponsor domain found: revolut.onelink.me\\n\",\n",
#     "      \"New sponsor domain found: hoyo.link\\n\",\n",
#     "      \"New sponsor domain found: gethap.pn\\n\",\n",
#     "      \"New sponsor domain found: letsplaysw.co\\n\",\n",
#     "      \"New sponsor domain found: emma-matelas.fr\\n\",\n",
#     "      \"New sponsor domain found: fr.air-up.com\\n\",\n",
#     "      \"New sponsor domain found: revolut.com\\n\",\n",
#     "      \"New sponsor domain found: tribunal-challenge-scolarite.odoo.com\\n\",\n",
#     "      \"New sponsor domain found: basic-fit.com\\n\",\n",
#     "      \"New sponsor domain found: paramountplus.com\\n\",\n",
#     "      \"New sponsor domain found: toodays.me\\n\",\n",
#     "      \"New sponsor domain found: lego.com\\n\",\n",
#     "      \"New sponsor domain found: tribunal-challenge.odoo.com\\n\",\n",
#     "      \"New sponsor domain found: tanks.ly\\n\",\n",
#     "      \"New sponsor domain found: s.wizzapp.com\\n\",\n",
#     "      \"New sponsor domain found: click.fan\\n\",\n",
#     "      \"New sponsor domain found: madtale.onelink.me\\n\",\n",
#     "      \"New sponsor domain found: shop.emma.fr\\n\",\n",
#     "      \"New sponsor domain found: opr.as\\n\",\n",
#     "      \"New sponsor domain found: ludoclub.onelink.me\\n\",\n",
#     "      \"New sponsor domain found: vr.igg.com\\n\",\n",
#     "      \"New sponsor domain found: bigeventfr-callofdragons.farlightgames.com\\n\",\n",
#     "      \"New sponsor domain found: tribunal-amixem1.odoo.com\\n\",\n",
#     "      \"New sponsor domain found: bitlifefr.onelink.me\\n\",\n",
#     "      \"New sponsor domain found: swcceu.onelink.me\\n\",\n",
#     "      \"New sponsor domain found: incogni.com\\n\",\n",
#     "      \"New sponsor domain found: displate.com\\n\",\n",
#     "      \"New sponsor domain found: concours-amixem1.odoo.com\\n\",\n",
#     "      \"New sponsor domain found: thetrainline.com\\n\",\n",
#     "      \"New sponsor domain found: spacefox.shop\\n\",\n",
#     "      \"New sponsor domain found: twitch.tv\\n\",\n",
#     "      \"New sponsor domain found: mtchm.de\\n\",\n",
#     "      \"New sponsor domain found: production-amixem.odoo.com\\n\",\n",
#     "      \"New sponsor domain found: reforestaction.com\\n\",\n",
#     "      \"New sponsor domain found: facebook.com\\n\",\n",
#     "      \"New sponsor domain found: ecoflow.com\\n\",\n",
#     "      \"New sponsor domain found: rebrand.ly\\n\",\n",
#     "      \"New sponsor domain found: krups.fr\\n\",\n",
#     "      \"New sponsor domain found: statesofsurvival.onelink.me\\n\",\n",
#     "      \"New sponsor domain found: app.bricks.co\\n\",\n",
#     "      \"New sponsor domain found: kingsgroup.onelink.me\\n\",\n",
#     "      \"New sponsor domain found: letsplaysw.com\\n\",\n",
#     "      \"New sponsor domain found: fr.ecoflow.com\\n\",\n",
#     "      \"New sponsor domain found: audible.fr\\n\",\n",
#     "      \"New sponsor domain found: boulanger.com\\n\",\n",
#     "      \"New sponsor domain found: m.boulanger.com\\n\",\n",
#     "      \"New sponsor domain found: ferme-villedieu.com\\n\",\n",
#     "      \"New sponsor domain found: playhearthstone.com\\n\",\n",
#     "      \"New sponsor domain found: lydia-app.com\\n\",\n",
#     "      \"New sponsor domain found: mhy.link\\n\",\n",
#     "      \"New sponsor domain found: thewrapinstitute.eu\\n\",\n",
#     "      \"New sponsor domain found: lens.google\\n\",\n",
#     "      \"New sponsor domain found: google.com\\n\",\n",
#     "      \"New sponsor domain found: google.fr\\n\",\n",
#     "      \"New sponsor domain found: translate.google.fr\\n\",\n",
#     "      \"New sponsor domain found: rhinoshield.fr\\n\",\n",
#     "      \"New sponsor domain found: strawpoll.me\\n\",\n",
#     "      \"New sponsor domain found: patron.me\\n\",\n",
#     "      \"New sponsor domain found: spektrparis.com\\n\",\n",
#     "      \"New sponsor domain found: yt.be\\n\",\n",
#     "      \"New sponsor domain found: service-public.fr\\n\",\n",
#     "      \"New sponsor domain found: get.maiar.com\\n\",\n",
#     "      \"New sponsor domain found: urlz.fr\\n\",\n",
#     "      \"New sponsor domain found: amzn.to\\n\",\n",
#     "      \"New sponsor domain found: reseaux.orange.fr\\n\",\n",
#     "      \"New sponsor domain found: ubi.li\\n\",\n",
#     "      \"New sponsor domain found: smarturl.it\\n\",\n",
#     "      \"New sponsor domain found: nerf-games.fr\\n\",\n",
#     "      \"New sponsor domain found: nerf.hasbro.com\\n\",\n",
#     "      \"New sponsor domain found: shop.wankil.fr\\n\",\n",
#     "      \"New sponsor domain found: biomeskateboard.fr\\n\",\n",
#     "      \"New sponsor domain found: clcr.me\\n\",\n",
#     "      \"New sponsor domain found: ufostalker.com\\n\",\n",
#     "      \"New sponsor domain found: maps.esri.com\\n\",\n",
#     "      \"New sponsor domain found: konard.github.io\\n\",\n",
#     "      \"New sponsor domain found: futureme.org\\n\",\n",
#     "      \"New sponsor domain found: dinosaurpictures.org\\n\",\n",
#     "      \"New sponsor domain found: letsplay.ouigo.com\\n\",\n",
#     "      \"New sponsor domain found: lines.chromeexperiments.com\\n\",\n",
#     "      \"New sponsor domain found: you.regettingold.com\\n\",\n",
#     "      \"New sponsor domain found: eu.novritsch.com\\n\",\n",
#     "      \"New sponsor domain found: tiny.cc\\n\",\n",
#     "      \"New sponsor domain found: pixly.go2cloud.org\\n\",\n",
#     "      \"New sponsor domain found: emeraude-escape.com\\n\",\n",
#     "      \"New sponsor domain found: fr.yamaha.com\\n\",\n",
#     "      \"New sponsor domain found: n26.com\\n\",\n",
#     "      \"New sponsor domain found: shdw.me\\n\",\n",
#     "      \"New sponsor domain found: castorama.fr\\n\",\n",
#     "      \"New sponsor domain found: philips.fr\\n\",\n",
#     "      \"New sponsor domain found: dorcelstore.com\\n\",\n",
#     "      \"New sponsor domain found: ldlc.com\\n\",\n",
#     "      \"New sponsor domain found: pathe.fr\\n\",\n",
#     "      \"New sponsor domain found: chamrousse.com\\n\",\n",
#     "      \"New sponsor domain found: dressclub.fr\\n\",\n",
#     "      \"New sponsor domain found: iproteck.com\\n\",\n",
#     "      \"New sponsor domain found: monsieurcerf.com\\n\",\n",
#     "      \"New sponsor domain found: breizh-cool.bzh\\n\",\n",
#     "      \"New sponsor domain found: paintball-sensation.fr\\n\",\n",
#     "      \"New sponsor domain found: wanteeed.com\\n\",\n",
#     "      \"New sponsor domain found: fr.shopping.rakuten.com\\n\",\n",
#     "      \"New sponsor domain found: enfantsdudesert.org\\n\",\n",
#     "      \"New sponsor domain found: Amixem.schoolmouv.fr\\n\",\n",
#     "      \"New sponsor domain found: amixem.schoolmouv.fr\\n\",\n",
#     "      \"New sponsor domain found: igg.com\\n\",\n",
#     "      \"New sponsor domain found: la-spa.fr\\n\",\n",
#     "      \"New sponsor domain found: 4ocean.com\\n\",\n",
#     "      \"New sponsor domain found: cancerdusein.org\\n\",\n",
#     "      \"New sponsor domain found: onepl.us\\n\",\n",
#     "      \"New sponsor domain found: plus.google.com\\n\",\n",
#     "      \"New sponsor domain found: justcause.com\\n\",\n",
#     "      \"New sponsor domain found: qwikmatch.app.link\\n\",\n",
#     "      \"New sponsor domain found: en.idcgames.com\\n\",\n",
#     "      \"New sponsor domain found: crossshopper.com\\n\",\n",
#     "      \"New sponsor domain found: enceinteplus.fr\\n\",\n",
#     "      \"New sponsor domain found: recylum.com\\n\",\n",
#     "      \"New sponsor domain found: neva.ly\\n\",\n",
#     "      \"New sponsor domain found: twitter.com\\n\",\n",
#     "      \"New sponsor domain found: goo.gl\\n\",\n",
#     "      \"New sponsor domain found: yourkenzoworld.com\\n\",\n",
#     "      \"New sponsor domain found: steep.ubisoft.com\\n\"\n",
#     "     ]\n",
#     "    }\n",
#     "   ],\n",
#     "   \"execution_count\": 31\n",
#     "  },\n",
#     "  {\n",
#     "   \"metadata\": {\n",
#     "    \"ExecuteTime\": {\n",
#     "     \"end_time\": \"2025-11-04T14:58:55.492732Z\",\n",
#     "     \"start_time\": \"2025-11-04T14:58:55.468773Z\"\n",
#     "    }\n",
#     "   },\n",
#     "   \"cell_type\": \"code\",\n",
#     "   \"source\": [\n",
#     "    \"data = pd.array(sponsors)\\n\",\n",
#     "    \"save_to_csv(data, \\\"sponsors.csv\\\")\"\n",
#     "   ],\n",
#     "   \"id\": \"2581cf9cac21b669\",\n",
#     "   \"outputs\": [],\n",
#     "   \"execution_count\": 34\n",
#     "  }\n",
#     " ],\n",
#     " \"metadata\": {\n",
#     "  \"kernelspec\": {\n",
#     "   \"name\": \"python3\",\n",
#     "   \"language\": \"python\",\n",
#     "   \"display_name\": \"Python 3 (ipykernel)\"\n",
#     "  }\n",
#     " },\n",
#     " \"nbformat\": 4,\n",
#     " \"nbformat_minor\": 5\n",
#     "}\n"
#    ],
#    "id": "5a0803d04d62661d"
#   }
#  ],
#  "metadata": {},
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
